# %%
# %matplotlib inline
# from sklearn.datasets import load_digits
# from sklearn.model_selection import train_test_split
# from sklearn.naive_bayes import GaussianNB

# X, y = load_digits(return_X_y=True)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
# nb = GaussianNB()
# nb.fit(X_train, y_train)
# predicted_probas = nb.predict_proba(X_test)

# print(X, y)
# print(X.shape, y.shape)
# print("\n\n", predicted_probas, predicted_probas.shape, "\n\n")
# # The magic happens here
# import matplotlib.pyplot as plt
# import scikitplot as skplt
# print(y_test.shape)
# print(predicted_probas.shape)
# skplt.metrics.plot_roc(y_test, predicted_probas)
# plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits
X, y = load_digits(return_X_y=True)

from sklearn.ensemble import RandomForestClassifier
random_forest_clf = RandomForestClassifier(n_estimators=5, max_depth=5, random_state=1)

from sklearn.model_selection import cross_val_predict
predictions = cross_val_predict(random_forest_clf, X, y, cv = 3)

from sklearn.model_selection import cross_val_predict
predictions = cross_val_predict(random_forest_clf, X, y, cv = 3)

import scikitplot as skplt
skplt.metrics.plot_confusion_matrix(y, predictions, normalize=True)

plt.show()
